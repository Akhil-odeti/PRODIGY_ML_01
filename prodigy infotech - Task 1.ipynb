# %%
import pandas as pd
data = pd.read_csv("train.csv")
data
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
data.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
data.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
# as per the given statement we cosindering only few freatures are import to us 
# its update it first
required_col = ["GrLivArea", "BedroomAbvGr", "FullBath","1stFlrSF","2ndFlrSF","LotArea","OverallQual","SalePrice"]
updated_data = data[required_col]
updated_data
# Out:
#       GrLivArea  BedroomAbvGr  FullBath  1stFlrSF  2ndFlrSF  LotArea  \
# 0          1710             3         2       856       854     8450
# 1          1262             3         2      1262         0     9600
# 2          1786             3         2       920       866    11250
# 3          1717             3         1       961       756     9550
# 4          2198             4         2      1145      1053    14260
# ...         ...           ...       ...       ...       ...      ...
# 1455       1647             3         2       953       694     7917
# 1456       2073             3         2      2073         0    13175
# 1457       2340             4         2      1188      1152     9042
# 1458       1078             2         1      1078         0     9717
# 1459       1256             3         1      1256         0     9937
#
#       OverallQual  SalePrice
# 0               7     208500
# 1               6     181500
# 2               7     223500
# ...

# %%
updated_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   GrLivArea     1460 non-null   int64
#  1   BedroomAbvGr  1460 non-null   int64
#  2   FullBath      1460 non-null   int64
#  3   1stFlrSF      1460 non-null   int64
#  4   2ndFlrSF      1460 non-null   int64
#  5   LotArea       1460 non-null   int64
#  6   OverallQual   1460 non-null   int64
#  7   SalePrice     1460 non-null   int64
# dtypes: int64(8)
# memory usage: 91.4 KB

# %%
updated_data.isnull().sum()
# Out:
# GrLivArea       0
# BedroomAbvGr    0
# FullBath        0
# 1stFlrSF        0
# 2ndFlrSF        0
# LotArea         0
# OverallQual     0
# SalePrice       0
# dtype: int64

# %%
updated_data.describe()
# Out:
#          GrLivArea  BedroomAbvGr     FullBath     1stFlrSF     2ndFlrSF  \
# count  1460.000000   1460.000000  1460.000000  1460.000000  1460.000000
# mean   1515.463699      2.866438     1.565068  1162.626712   346.992466
# std     525.480383      0.815778     0.550916   386.587738   436.528436
# min     334.000000      0.000000     0.000000   334.000000     0.000000
# 25%    1129.500000      2.000000     1.000000   882.000000     0.000000
# 50%    1464.000000      3.000000     2.000000  1087.000000     0.000000
# 75%    1776.750000      3.000000     2.000000  1391.250000   728.000000
# max    5642.000000      8.000000     3.000000  4692.000000  2065.000000
#
#              LotArea  OverallQual      SalePrice
# count    1460.000000  1460.000000    1460.000000
# mean    10516.828082     6.099315  180921.195890
# std      9981.264932     1.382997   79442.502883
# min      1300.000000     1.000000   34900.000000
# 25%      7553.500000     5.000000  129975.000000
# ...

# %%
col = updated_data.columns
col
columns = col[:-1]
columns
# Out:
# Index(['GrLivArea', 'BedroomAbvGr', 'FullBath', '1stFlrSF', '2ndFlrSF',
#        'LotArea', 'OverallQual'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
for column in columns:
    plt.figure()
    sns.boxplot(data = updated_data,x = updated_data[column])
    plt.title("boxplot of" + column)
    plt.show()

# %%
import pandas as pd


def remove_outliers(df, columns):
    for column in columns:
        Q1 = df[column].quantile(0.25)
        Q3 = df[column].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR
        df = df[(df[column] >= lower_bound) & (df[column] <= upper_bound)]
    return df
cleaned_data = remove_outliers(updated_data, columns)
print("Original data shape:", updated_data.shape)
print("Cleaned data shape:", cleaned_data.shape)
# Out:
# Original data shape: (1460, 8)
# Cleaned data shape: (1314, 8)

# %%
data = cleaned_data
data
# Out:
#       GrLivArea  BedroomAbvGr  FullBath  1stFlrSF  2ndFlrSF  LotArea  \
# 0          1710             3         2       856       854     8450
# 1          1262             3         2      1262         0     9600
# 2          1786             3         2       920       866    11250
# 3          1717             3         1       961       756     9550
# 4          2198             4         2      1145      1053    14260
# ...         ...           ...       ...       ...       ...      ...
# 1455       1647             3         2       953       694     7917
# 1456       2073             3         2      2073         0    13175
# 1457       2340             4         2      1188      1152     9042
# 1458       1078             2         1      1078         0     9717
# 1459       1256             3         1      1256         0     9937
#
#       OverallQual  SalePrice
# 0               7     208500
# 1               6     181500
# 2               7     223500
# ...

# %%
data.reset_index(drop = True , inplace = True )

# %%
data
# Out:
#       GrLivArea  BedroomAbvGr  FullBath  1stFlrSF  2ndFlrSF  LotArea  \
# 0          1710             3         2       856       854     8450
# 1          1262             3         2      1262         0     9600
# 2          1786             3         2       920       866    11250
# 3          1717             3         1       961       756     9550
# 4          2198             4         2      1145      1053    14260
# ...         ...           ...       ...       ...       ...      ...
# 1309       1647             3         2       953       694     7917
# 1310       2073             3         2      2073         0    13175
# 1311       2340             4         2      1188      1152     9042
# 1312       1078             2         1      1078         0     9717
# 1313       1256             3         1      1256         0     9937
#
#       OverallQual  SalePrice
# 0               7     208500
# 1               6     181500
# 2               7     223500
# ...

# %%
for column in columns:
    plt.figure()
    sns.boxplot(data = data, x= data[column])
    plt.title("boxplot of" + column)
    plt.show()

# %%
data.corr()
# Out:
#               GrLivArea  BedroomAbvGr  FullBath  1stFlrSF  2ndFlrSF   LotArea  \
# GrLivArea      1.000000      0.514760  0.619993  0.436680  0.696974  0.372863
# BedroomAbvGr   0.514760      1.000000  0.293638  0.058738  0.492657  0.317887
# FullBath       0.619993      0.293638  1.000000  0.340518  0.381332  0.169817
# 1stFlrSF       0.436680      0.058738  0.340518  1.000000 -0.335168  0.397466
# 2ndFlrSF       0.696974      0.492657  0.381332 -0.335168  1.000000  0.076296
# LotArea        0.372863      0.317887  0.169817  0.397466  0.076296  1.000000
# OverallQual    0.594817      0.102700  0.548151  0.447095  0.273047  0.201238
# SalePrice      0.713470      0.170079  0.565755  0.599710  0.276665  0.404933
#
#               OverallQual  SalePrice
# GrLivArea        0.594817   0.713470
# BedroomAbvGr     0.102700   0.170079
# FullBath         0.548151   0.565755
# 1stFlrSF         0.447095   0.599710
# 2ndFlrSF         0.273047   0.276665
# LotArea          0.201238   0.404933
# ...

# %%
corr_dict = {}
for column in columns:
    corr = data[column].corr(data["SalePrice"])
    corr_dict[column] = corr

print(corr_dict)
# Out:
# {'GrLivArea': 0.7134696135850598, 'BedroomAbvGr': 0.17007949606706027, 'FullBath': 0.5657547181316099, '1stFlrSF': 0.5997096921701854, '2ndFlrSF': 0.276665165916354, 'LotArea': 0.40493348342060276, 'OverallQual': 0.8170097738393358}

# %%
# from sklearn.preprocessing import StandardScaler

# # Instantiate the StandardScaler
# scaler = StandardScaler()

# # Fit the scaler to your data
# scaler.fit(data)
# data1 = scaler.transform(data)
# data1
# data1 = pd.DataFrame(data1)
# data1
data
# Out:
#       GrLivArea  BedroomAbvGr  FullBath  1stFlrSF  2ndFlrSF  LotArea  \
# 0          1710             3         2       856       854     8450
# 1          1262             3         2      1262         0     9600
# 2          1786             3         2       920       866    11250
# 3          1717             3         1       961       756     9550
# 4          2198             4         2      1145      1053    14260
# ...         ...           ...       ...       ...       ...      ...
# 1309       1647             3         2       953       694     7917
# 1310       2073             3         2      2073         0    13175
# 1311       2340             4         2      1188      1152     9042
# 1312       1078             2         1      1078         0     9717
# 1313       1256             3         1      1256         0     9937
#
#       OverallQual  SalePrice
# 0               7     208500
# 1               6     181500
# 2               7     223500
# ...

# %%
x = data.iloc[:,:-1]
print(x)
y = data.iloc[:,-1]
print(y)
# Out:
#       GrLivArea  BedroomAbvGr  FullBath  1stFlrSF  2ndFlrSF  LotArea  \
# 0          1710             3         2       856       854     8450
# 1          1262             3         2      1262         0     9600
# 2          1786             3         2       920       866    11250
# 3          1717             3         1       961       756     9550
# 4          2198             4         2      1145      1053    14260
# ...         ...           ...       ...       ...       ...      ...
# 1309       1647             3         2       953       694     7917
# 1310       2073             3         2      2073         0    13175
# 1311       2340             4         2      1188      1152     9042
# 1312       1078             2         1      1078         0     9717
# 1313       1256             3         1      1256         0     9937
#
#       OverallQual
# 0               7
# 1               6
# 2               7
# 3               7
# 4               8
# ...           ...
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
# x_train,x_test,y_train,y_test = train_test_split(x,y,test_size =0.2,random_state = 0)

# %%
# from sklearn.linear_model import LinearRegression
# model =  LinearRegression()
# model.fit(x_train,y_train)

# %%
# y_pred = model.predict(x_test)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %%
# y_pred

# %%
# from sklearn.metrics import accuracy_score

# %%
# accuracy = accuracy_score(y_test,y_pred)

# %%
# score = r2_score(y_test,y_pred)

# %%
# score

# %%
# Import necessary libraries for feature engineering
from sklearn.preprocessing import PolynomialFeatures
from sklearn.feature_selection import SelectKBest, f_regression
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor

# Add polynomial features
poly = PolynomialFeatures(degree=2, include_bias=False)
x_poly = poly.fit_transform(x)

selector = SelectKBest(score_func=f_regression, k='all')
x_selected = selector.fit_transform(x_poly, y)

x_train, x_test, y_train, y_test = train_test_split(x_selected, y, test_size=0.2, random_state=42)
model = LinearRegression()
model.fit(x_train, y_train)
y_pred = model.predict(x_test)

train_score = model.score(x_train, y_train)
test_score = model.score(x_test, y_test)

print('Training Score:', train_score)
print('Testing Score:', test_score)
score = r2_score(y_test, y_pred)
print("R2 Score ", score)
# Out:
# Training Score: 0.8594758102024578
# Testing Score: 0.845426866201782
# R2 Score  0.845426866201782

# %%
# !pip install xgboost

# %%
import xgboost as xgb

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# Train the XGBoost model
model = xgb.XGBRegressor(objective='reg:squarederror', n_estimators=100,learning_rate=0.1, max_depth=4)
model.fit(x_train, y_train)
train_score = model.score(x_train, y_train)
test_score = model.score(x_test, y_test)
print('Training Score:', train_score)
print('Testing Score:', test_score)
# Out:
# Training Score: 0.9360467855170085
# Testing Score: 0.8237672020483005

# %%
y_pred = model.predict(x_test)
y_pred
score = r2_score(y_test, y_pred)
score
# Out:
# 0.8237672020483005

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

model = RandomForestRegressor(n_estimators=100, random_state=42)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

mse = mean_squared_error(y_test, y_pred)
print(f'Mean Squared Error: {mse}')
score = r2_score(y_test, y_pred)
print( score)
# Out:
# Mean Squared Error: 959993220.6292135
# 0.8194075745847478
